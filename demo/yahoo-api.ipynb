# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

import yfinance as yf

# %%
engine = create_engine("postgresql+psycopg2://ttl:50770329@db:5432/yahoo")

# %%
tickers = [  "2330.TW", "2451.TW" ]

# %%
columns = [ 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume' ]

# %%
stock = yf.download(
    tickers=tickers,
    period='1d',
    interval="1m",
    ignore_tz=False
)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
stock.head()
# Out:
#                           Adj Close           Close            High  \
#                             2330.TW 2451.TW 2330.TW 2451.TW 2330.TW
# Datetime
# 2022-11-17 09:00:00+08:00     481.5    66.0   481.5    66.0   483.0
# 2022-11-17 09:01:00+08:00     481.5     NaN   481.5     NaN   482.0
# 2022-11-17 09:02:00+08:00     482.5    66.0   482.5    66.0   482.5
# 2022-11-17 09:03:00+08:00     482.5     NaN   482.5     NaN   482.5
# 2022-11-17 09:04:00+08:00     482.5     NaN   482.5     NaN   482.5
#
#                                          Low            Open          Volume  \
#                              2451.TW 2330.TW 2451.TW 2330.TW 2451.TW 2330.TW
# Datetime
# 2022-11-17 09:00:00+08:00  66.099998   481.5    66.0   482.5    66.0       0
# 2022-11-17 09:01:00+08:00        NaN   481.0     NaN   481.5     NaN  669000
# 2022-11-17 09:02:00+08:00  66.000000   481.5    66.0   482.0    66.0  325000
# 2022-11-17 09:03:00+08:00        NaN   482.0     NaN   482.0     NaN  108000
# 2022-11-17 09:04:00+08:00        NaN   482.0     NaN   482.0     NaN  230000
#
#
#                           2451.TW
# Datetime
# 2022-11-17 09:00:00+08:00     0.0
# 2022-11-17 09:01:00+08:00     NaN
# 2022-11-17 09:02:00+08:00  9200.0
# 2022-11-17 09:03:00+08:00     NaN
# 2022-11-17 09:04:00+08:00     NaN

# %%
stock.columns
# Out:
# MultiIndex([('Adj Close', '2330.TW'),
#             ('Adj Close', '2451.TW'),
#             (    'Close', '2330.TW'),
#             (    'Close', '2451.TW'),
#             (     'High', '2330.TW'),
#             (     'High', '2451.TW'),
#             (      'Low', '2330.TW'),
#             (      'Low', '2451.TW'),
#             (     'Open', '2330.TW'),
#             (     'Open', '2451.TW'),
#             (   'Volume', '2330.TW'),
#             (   'Volume', '2451.TW')],
#            )

# %%
stocks = []
for ticker in tickers:
    tmp_stock = stock[ [ (column, ticker) for column in columns] ].copy()
    tmp_stock.columns = columns
    tmp_stock['Ticker'] = ticker
    tmp_stock = tmp_stock[ ["Ticker"]+columns ]
    tmp_stock.reset_index(inplace=True)
    tmp_stock.dropna(subset=columns, how="all", axis=0, inplace=True)
    stocks += [ tmp_stock ]

# %%
stock = pd.concat(stocks)

# %%
stock.head()
# Out:
#                      Datetime   Ticker   Adj Close       Close        High  \
# 0   2022-11-17 09:00:00+08:00  2330.TW  481.500000  481.500000  483.000000
# 1   2022-11-17 09:01:00+08:00  2330.TW  481.500000  481.500000  482.000000
# 2   2022-11-17 09:02:00+08:00  2330.TW  482.500000  482.500000  482.500000
# 3   2022-11-17 09:03:00+08:00  2330.TW  482.500000  482.500000  482.500000
# 4   2022-11-17 09:04:00+08:00  2330.TW  482.500000  482.500000  482.500000
# ..                        ...      ...         ...         ...         ...
# 260 2022-11-17 13:20:00+08:00  2451.TW   65.800003   65.800003   65.800003
# 261 2022-11-17 13:21:00+08:00  2451.TW   65.800003   65.800003   65.800003
# 263 2022-11-17 13:23:00+08:00  2451.TW   65.699997   65.699997   65.699997
# 264 2022-11-17 13:24:00+08:00  2451.TW   65.900002   65.900002   65.900002
# 265 2022-11-17 13:30:00+08:00  2451.TW   66.000000   66.000000   66.000000
#
#             Low        Open    Volume
# 0    481.500000  482.500000       0.0
# 1    481.000000  481.500000  669000.0
# 2    481.500000  482.000000  325000.0
# 3    482.000000  482.000000  108000.0
# 4    482.000000  482.000000  230000.0
# ..          ...         ...       ...
# 260   65.800003   65.800003    1000.0
# 261   65.800003   65.800003    3000.0
# 263   65.699997   65.699997    1000.0
# 264   65.900002   65.900002    4100.0
# 265   66.000000   66.000000       0.0
#
# [344 rows x 8 columns]

# %%
stock.columns = [ ''.join(x.lower().split()) for x in stock.columns.tolist() ]

# %%
stock.head()
# Out:
#                    datetime   ticker  adjclose  close   high    low   open  \
# 0 2022-11-17 09:00:00+08:00  2330.TW     481.5  481.5  483.0  481.5  482.5
# 1 2022-11-17 09:01:00+08:00  2330.TW     481.5  481.5  482.0  481.0  481.5
# 2 2022-11-17 09:02:00+08:00  2330.TW     482.5  482.5  482.5  481.5  482.0
# 3 2022-11-17 09:03:00+08:00  2330.TW     482.5  482.5  482.5  482.0  482.0
# 4 2022-11-17 09:04:00+08:00  2330.TW     482.5  482.5  482.5  482.0  482.0
#
#      volume
# 0       0.0
# 1  669000.0
# 2  325000.0
# 3  108000.0
# 4  230000.0

# %%
stock.to_sql(
    "yfinance",
    engine,
    if_exists="append",
    index=False,
    method="multi"
)
# Out:
# 344

# %%
pd.read_sql('select * from yfinance', engine)
# Out:
#                      datetime   ticker    adjclose       close        high  \
# 0   2022-11-17 01:00:00+00:00  2330.TW  481.500000  481.500000  483.000000
# 1   2022-11-17 01:01:00+00:00  2330.TW  481.500000  481.500000  482.000000
# 2   2022-11-17 01:02:00+00:00  2330.TW  482.500000  482.500000  482.500000
# 3   2022-11-17 01:03:00+00:00  2330.TW  482.500000  482.500000  482.500000
# 4   2022-11-17 01:04:00+00:00  2330.TW  482.500000  482.500000  482.500000
# ..                        ...      ...         ...         ...         ...
# 339 2022-11-17 05:20:00+00:00  2451.TW   65.800003   65.800003   65.800003
# 340 2022-11-17 05:21:00+00:00  2451.TW   65.800003   65.800003   65.800003
# 341 2022-11-17 05:23:00+00:00  2451.TW   65.699997   65.699997   65.699997
# 342 2022-11-17 05:24:00+00:00  2451.TW   65.900002   65.900002   65.900002
# 343 2022-11-17 05:30:00+00:00  2451.TW   66.000000   66.000000   66.000000
#
#             low        open  volume
# 0    481.500000  482.500000       0
# 1    481.000000  481.500000  669000
# 2    481.500000  482.000000  325000
# 3    482.000000  482.000000  108000
# 4    482.000000  482.000000  230000
# ..          ...         ...     ...
# 339   65.800003   65.800003    1000
# 340   65.800003   65.800003    3000
# 341   65.699997   65.699997    1000
# 342   65.900002   65.900002    4100
# 343   66.000000   66.000000       0
#
# [344 rows x 8 columns]
